# %%
# Databricks notebook source
print("Databricks Git integration is working perfectly!")

data = [("Shakti", "Data Engineering"), ("Databricks", "Cloud")]
df = spark.createDataFrame(data, ["User", "Technology"])
display(df)
